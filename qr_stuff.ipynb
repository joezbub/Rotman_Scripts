# %%
import pandas as pd
df = pd.read_parquet('nov7/clean.parquet')
# df['adjpc'] = df['prccd'] / df['ajexdi']
# df = df.sort_values(['datadate', 'tic']).reset_index(drop=True).dropna(subset=['adjpc'])
df
# Out:
#           GVKEY      LINKDT   LINKENDDT    datadate    tic  ajexdi  \
# 0        126554  1999-11-18           E  2010-01-04      A  1.0000
# 1          1045  1962-01-31  2012-01-04  2010-01-04  AAMRQ  1.0000
# 2          1076  1993-01-01  2010-11-30  2010-01-04  AAN.2  1.5000
# 3         21542  1991-01-03           E  2010-01-04   AAON  5.0625
# 4        145977  2001-11-29           E  2010-01-04    AAP  1.0000
# ...         ...         ...         ...         ...    ...     ...
# 5105150   35005  2019-04-18           E  2023-11-06     ZM  1.0000
# 5105151   33037  2018-03-16           E  2023-11-06     ZS  1.0000
# 5105152   13721  2013-02-01           E  2023-11-06    ZTS  1.0000
# 5105153   33232  2018-04-12           E  2023-11-06    ZUO  1.0000
# 5105154  180474  2012-03-29           E  2023-11-06    ZWS  1.0000
#
#                cshoc      cshtrd   prccd    prchd     prcld   prcod  \
# 0        348831000.0   2729240.0   31.30   31.630   31.1314   31.39
# ...

# %%
df.loc[df['tic'] == 'AAPL'].plot(x='datadate', y='adjpc')
# Out:
# <Axes: xlabel='datadate'>

# %%
list(df)
# Out:
# ['GVKEY',
#  'LINKDT',
#  'LINKENDDT',
#  'datadate',
#  'tic',
#  'ajexdi',
#  'cshoc',
#  'cshtrd',
#  'prccd',
#  'prchd',
#  'prcld',
#  'prcod',
#  'cik',
#  'ggroup',
#  'gind',
#  'gsector',
#  'gsubind',
#  'adjpc']

# %%
for index, row in df.iterrows():
    if row['datadate'] == "2023-11-03":
        print(row['datadate'], row['tic'], row['adjpc'])
# Out:
# 2023-11-03 BLTE 39.03
# 2023-11-03 SNDX 14.8
# 2023-11-03 GOGO 11.12
# 2023-11-03 AVPT 7.6
# 2023-11-03 VRTS 201.03
# 2023-11-03 PEBO 28.48
# 2023-11-03 RXRX 5.91
# 2023-11-03 ATUS 2.9
# 2023-11-03 HTLF 29.7
# 2023-11-03 MRTN 18.36
# 2023-11-03 STC 46.97
# 2023-11-03 STBA 28.54
# 2023-11-03 GBX 37.47
# 2023-11-03 ROVR 6.51
# 2023-11-03 TMDX 42.62
# 2023-11-03 OFG 31.84
# 2023-11-03 SHEN 24.74
# 2023-11-03 CHCO 96.91
# 2023-11-03 HLX 10.19
# 2023-11-03 WABC 49.36
# 2023-11-03 IESC 61.86
# 2023-11-03 EVRI 11.5
# 2023-11-03 DMLP 28.4
# 2023-11-03 PX 10.08
# 2023-11-03 B 22.48
# 2023-11-03 GIII 27.18
# 2023-11-03 HE 13.85
# 2023-11-03 SAFE 17.79
# 2023-11-03 NIC 76.96
# 2023-11-03 BRP 22.49
# 2023-11-03 AVID 27.04
# 2023-11-03 TRS 24.61
# 2023-11-03 JBI 10.07
# 2023-11-03 CLDX 25.98
# 2023-11-03 PFS 15.53
# 2023-11-03 GTY 28.21
# 2023-11-03 SEMR 8.15
# 2023-11-03 NKLA 1.14
# 2023-11-03 HWKN 60.56
# 2023-11-03 SYBT 42.77
# 2023-11-03 PCRX 31.04
# 2023-11-03 CDRE 28.6
# ...
